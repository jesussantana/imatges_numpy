# %% [markdown]
# # IT Academy - Data Science amb Python
# ## Tasca 2-A: Estructura de una Matriu
#
# ###  [Github Estructura de una Matriu](https://github.com/jesussantana/imatges_numpy)

# %% [markdown]
# ###  Exercici 1
# - Crea un np.array de una dimension, que inclogui l'almenys 8 nombres sencers, data type int64. Mostra la dimensió i la forma de la matriu.

# %%
import numpy as np
from numpy import random
import numpy.ma as ma

array = random.randint(100, size = (8))
array
# Out:
# array([37, 46, 66, 42, 54, 40, 55, 59])

# %%
print(array.ndim)
array.dtype
# Out:
# 1
# dtype('int64')

# %%
array64 = array.astype(np.int64)
array64.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ###  Exercici 2
# - De la matriu de l'exercici 1, calcula el valor mitjà dels valors introduïts i resta la mitjana resultant de cada un dels valors de la matriu..

# %%
mean_calculation = array64.mean()
print(mean_calculation)
# Out:
# 49.875

# %%
array64 - mean_calculation
# Out:
# array([-12.875,  -3.875,  16.125,  -7.875,   4.125,  -9.875,   5.125,
#          9.125])

# %% [markdown]
# ###  Exercici 3
# - Crea una matriu bidimensional amb una forma de 5 x 5. Extreu el valor màxim de la matriu, i els valors màxims de cadascun dels seus eixos.

# %%
array =random.randint(0,100,(5, 5))
array64 = array.astype(np.int64)
array64
# Out:
# array([[10,  3, 36, 80, 20],
#        [54, 86, 45, 95, 90],
#        [57, 38, 25, 37, 26],
#        [ 1, 98, 58, 52, 74],
#        [10, 67, 38, 31, 66]])

# %%
array64.max()
# Out:
# 98

# %%
np.amax(array64, axis=1)
# Out:
# array([80, 95, 57, 98, 67])

# %%
np.amax(array64, axis=0)
# Out:
# array([57, 98, 58, 95, 90])

# %% [markdown]
# ###  Exercici 4
# - Mostreu-me amb exemples de diferents matrius, la regla fonamental de Broadcasting que diu : "les matrius es poden transmetre / broadcast entre si les seves dimensions coincideixen o si una de les matrius té una mida d'1".

# %%
x = np.repeat((0, 5, 10, 15, 20), 3).reshape(5, 3)
y = np.repeat((0, 1, 2) ,5).reshape(3, 5).T
print(x)
print(y)
print(x + y)
# Out:
# [[ 0  0  0]
#  [ 5  5  5]
#  [10 10 10]
#  [15 15 15]
#  [20 20 20]]
# [[0 1 2]
#  [0 1 2]
#  [0 1 2]
#  [0 1 2]
#  [0 1 2]]
# [[ 0  1  2]
#  [ 5  6  7]
#  [10 11 12]
#  [15 16 17]
#  [20 21 22]]

# %%
x = np.array((0, 4, 8, 10)).reshape(4, 1)
y = np.array((0, 1, 3))
print(x)
print(y)
print(x * y)
# Out:
# [[ 0]
#  [ 4]
#  [ 8]
#  [10]]
# [0 1 3]
# [[ 0  0  0]
#  [ 0  4 12]
#  [ 0  8 24]
#  [ 0 10 30]]

# %% [markdown]
# ###  Exercici 5
# - Utilitza la Indexació per extreure els valors d'una columna i una fila de la matriu. I suma els seus valors.

# %%
x = random.randint(0,100,(4,4))
x
# Out:
# array([[74, 72, 61, 64],
#        [19, 14, 42, 74],
#        [ 8, 47, 58, 66],
#        [17, 23, 20, 17]])

# %%
a = x[0]
a
# Out:
# array([74, 72, 61, 64])

# %%
b = x[:,2]
b
# Out:
# array([61, 42, 58, 20])

# %%
a + b
# Out:
# array([135, 114, 119,  84])

# %% [markdown]
# ###  Exercici 6
# - Mask la matriu anterior, realitzeu un càlcul booleà vectoritzat, agafant cada element i comprovant si es divideix uniformement per quatre.
#
# - Això retorna una matriu de mask de la mateixa forma amb els resultats elementals del càlcul.

# %%
y = x.view(ma.MaskedArray)
y
# Out:
# masked_array(
#   data=[[74, 72, 61, 64],
#         [19, 14, 42, 74],
#         [ 8, 47, 58, 66],
#         [17, 23, 20, 17]],
#   mask=False,
#   fill_value=999999)

# %%
b = y % 4 == 0
b
# Out:
# masked_array(
#   data=[[False,  True, False,  True],
#         [False, False, False, False],
#         [ True, False, False, False],
#         [False, False,  True, False]],
#   mask=False,
#   fill_value=True)

# %% [markdown]
# ###  Exercici 7
# - A continuació, utilitzeu aquesta màscara per indexar a la matriu de números original. Això fa que la matriu perdi la seva forma original, reduint-la a una dimensió, però encara obteniu les dades que esteu cercant.

# %%
index_matrix= ma.array(x, mask = b)
index_matrix
# Out:
# masked_array(
#   data=[[74, --, 61, --],
#         [19, 14, 42, 74],
#         [--, 47, 58, 66],
#         [17, 23, --, 17]],
#   mask=[[False,  True, False,  True],
#         [False, False, False, False],
#         [ True, False, False, False],
#         [False, False,  True, False]],
#   fill_value=999999)

# %%
a = index_matrix.compressed()
a
# Out:
# array([74, 61, 19, 14, 42, 74, 47, 58, 66, 17, 23, 17])

# %%
a.ndim
# Out:
# 1

# %% [markdown]
# ###  Exercici 8
# - Mostreu-me a veure que passa quan eliminem el canal G Verd o B Blau. Hauries de utizar la indexacion per selecciones el canal que voleu anul·lar.

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
from PIL import Image   
from scipy import ndimage
# %matplotlib inline

# %%
image = mpimg.imread("image_test.jpg")

# %%
image.dtype
# Out:
# dtype('uint8')

# %%
print(image.shape)
plt.imshow(image)
# Out:
# (317, 640, 3)

# %%
image1 = np.array(image[75:200,200:350])
plt.imshow(image1, interpolation = 'nearest')
print(image1.shape)
# Out:
# (125, 150, 3)

# %%
image2 = image[150:300]
plt.imshow(image2)
print(image2.shape)
# Out:
# (150, 640, 3)

# %%
image3 = np.copy(image)
image3[:,:,1] = 0
plt.title("Red & Blue Channel")
plt.imshow(image3)

# %%
image3 = np.copy(image)
image3[:,:,2] = 0
plt.title("Green & Blue Channel")
plt.imshow(image3)

# %%
mpimg.imsave("image_test_nearest.png", image1)

# %%
mpimg.imsave("image_test_slicing.png", image2)

# %%
mpimg.imsave("image_test_Red&Blue.png", image3)

# %%
mpimg.imsave("image_test_Green&Blue.png", image3)
